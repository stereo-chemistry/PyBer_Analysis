# %%
# %matplotlib inline

# %%
# Import depndencies
import matplotlib.pyplot as plt

# %%
# give x-axis a list of strings for each month
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Give y-axis a list of floats of USD fares accumulated each month
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create plot
plt.plot(x_axis, y_axis)

# %%
# Create plot with ax.plt() method

fig, ax = plt.subplots()
ax.plot(x_axis, y_axis)

# %%
# Create plot with ax.plt() method

fig = plt.figure()
ax = fig.add_subplot()
ax.plot(x_axis, y_axis)

# %%
# Create the plot and add a label for the legend
plt.plot(x_axis, y_axis, label ='Boston', color="blue", marker="*", linewidth=2)

# Create labels for the x & y axes
plt.xlabel("Date")
plt.ylabel("Fare($)")

# Set the y limit between 0 & 45
plt.ylim(0, 45)

# Create title
plt.title("PyBer Fare by Month")

# Add legend
plt.legend()

# %%
# Needs work
fig, ax = plt.subplots()
ax.set_linewidth=500
ax.set_ylim(0, 45)
ax.set_ylabel('Fare($)')
ax.set_xlabel('Month')
ax.set_title('PyBer Fare by Month')
ax.plot(x_axis, y_axis)

# %%
# Give x-axis a list of strings for each month
x_axis = ["Jan", "Feb", "March", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Give y-axisa list of floats as the total fare accumulated for each month in USD
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create bar graph
plt.bar(x_axis, y_axis, color="green", label='Boston')

#Create labels for x & y axes
plt.xlabel("Month")
plt.ylabel("Fare($)")

# Create Title
plt.title("PyBer Fare by Month")

# Add legend
plt.legend()

# %%
# Create horizontal bar graph
plt.barh(x_axis, y_axis, color="magenta", label='Boston')

plt.xlabel("Months")
plt.ylabel("Fare($)")
plt.title("PyBer Fare by Month")
plt.gca().invert_yaxis()

plt.legend()

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

# %%
# Create bar graph with ax.plt() method
fig, ax = plt.subplots()
ax.bar(x_axis, y_axis, color="k", label='New York')
# Out:
# <BarContainer object of 12 artists>

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

y_axis_larger = []
for data in y_axis:
    y_axis_larger.append(data*3)

plt.title('PyBer Fare by Month')
plt.xlabel('Months')
plt.ylabel('Fare($)')

plt.plot(x_axis, y_axis, 'o')
plt.scatter(x_axis, y_axis, s=y_axis_larger)

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]


plt.title('PyBer Fare by Month')
plt.xlabel('Months')
plt.ylabel('Fare($)')

plt.plot(x_axis, y_axis, 'o')
plt.scatter(x_axis, y_axis, s=[i * 3 for i in y_axis])

# %%
# Set the x-axis to a list of strings for each month.
x_axis = ["Jan", "Feb", "Mar", "April", "May", "June", "July", "Aug", "Sept", "Oct", "Nov", "Dec"]

# Set the y-axis to a list of floats as the total fare in US dollars accumulated for each month.
y_axis = [10.02, 23.24, 39.20, 35.42, 32.34, 27.04, 43.82, 10.56, 11.85, 27.90, 20.71, 20.09]

fig, ax = plt.subplots()
ax.scatter(x_axis, y_axis, s=[i * 5 for i in y_axis], c='red')

# %%
colors = ["slateblue", "magenta", "lightblue", "green", "yellowgreen", "greenyellow", "yellow", "orange", "gold", "indianred", "tomato", "mistyrose"]
explode_values = (0, 0, 0, 0, 0, 0, 0.2, 0, 0, 0, 0, 0)
plt.subplots(figsize=(8,8))
plt.pie(y_axis, 
        explode=explode_values, 
        colors=colors, 
        labels=x_axis, 
        autopct='%.1f%%')
plt.show()
